# %% [markdown]
# In this notebook, we will use LSTM to predict stock price (more precisely, we are interested in the rise and fall of a stock price based on previous information) in Keras. I will also use more than one feature in my model, and it could be interesting for you to see how we can create the LSTM input data shape required by Keras in this case.
#
# Moreover, we are going to implement a manual Grid Search to tune the hyperparameters. We will also take advantage of Early Stopping and Callback to reduce the hyperparameter tunning time. To the best of my knowledge, the tunned model has the best result on this data in the Kaggle.

# %% [markdown]
# ## Contents
#
# * [Import Libraries and the Data](#1)
# * [Descriptive Analysis](#2)
#     - [Number of unique stock symbols](#21)
#     - [Choosing a Random Stock Symbol](#22)
#     - [plotting Price through Time](#23)
#     - [Fearure Scaling](#24)
#     - [Creating LSTM input data](#25)
# * [Train LSTM Model](#3)
# * [Hyperparameter Tunning](#4)
#     - [Introduction](#41)
#     - [Grid Search](#42)
#     - [Early Stopping and Callback](#43)
#     - [Choosing the Best Model](#44)
# * [Results](#5)

# %% [markdown]
# <a id="1"></a> <br>
# ## Import Libraries and the Data

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU
from keras.layers import Dropout
from sklearn.preprocessing import MinMaxScaler
from keras.models import load_model
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import itertools
import random
import os
import keras

for dirname, _, filenames in os.walk('.'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./volume.png
# ./Kaggle-problem presentation.docx
# ./2330_TW.csv
# ./best_model.keras
# ./驗證用.csv
# ./stock-price-prediction-lstm-hyperparameter-tuning.ipynb
# ./output.png
# ./data.png
# ./Kaggle-problem presentation.pdf
# ./2010.1.1~2024.4.1/^SOX(費城半導體).csv
# ./2010.1.1~2024.4.1/2330.TW(股息).csv
# ./2010.1.1~2024.4.1/TSM(ADR).csv
# ./2010.1.1~2024.4.1/2330.TW.csv
# ./.venv/pyvenv.cfg
# ./.venv/.gitignore
# ./.venv/bin/wheel3.11
# ./.venv/bin/import_pb_to_tensorboard
# ./.venv/bin/pyftsubset
# ./.venv/bin/markdown_py
# ./.venv/bin/jupyter-run
# ./.venv/bin/wheel3
# ./.venv/bin/activate.ps1
# ./.venv/bin/toco_from_protos
# ./.venv/bin/python3
# ./.venv/bin/ttx
# ./.venv/bin/python
# ./.venv/bin/pip3
# ./.venv/bin/ipython
# ./.venv/bin/pip-3.11
# ./.venv/bin/activate.fish
# ./.venv/bin/fonttools
# ./.venv/bin/wheel
# ./.venv/bin/python3.11
# ./.venv/bin/tf_upgrade_v2
# ./.venv/bin/wheel-3.11
# ./.venv/bin/activate_this.py
# ./.venv/bin/f2py
# ./.venv/bin/ipython3
# ./.venv/bin/pip
# ./.venv/bin/markdown-it
# ./.venv/bin/pip3.11
# ./.venv/bin/jupyter-troubleshoot
# ./.venv/bin/pygmentize
# ./.venv/bin/jupyter-migrate
# ./.venv/bin/tensorboard
# ./.venv/bin/tflite_convert
# ./.venv/bin/activate
# ./.venv/bin/activate.nu
# ./.venv/bin/normalizer
# ./.venv/bin/saved_model_cli
# ./.venv/bin/toco
# ./.venv/bin/jupyter-kernelspec
# ./.venv/bin/jupyter-kernel
# ./.venv/bin/jupyter
# ./.venv/bin/pyftmerge
# ./.venv/bin/activate.csh
# ./.venv/lib/python3.11/site-packages/threadpoolctl.py
# ./.venv/lib/python3.11/site-packages/pylab.py
# ./.venv/lib/python3.11/site-packages/decorator.py
# ./.venv/lib/python3.11/site-packages/ipykernel_launcher.py
# ./.venv/lib/python3.11/site-packages/wheel-0.43.0.virtualenv
# ./.venv/lib/python3.11/site-packages/_virtualenv.py
# ./.venv/lib/python3.11/site-packages/distutils-precedence.pth
# ./.venv/lib/python3.11/site-packages/_virtualenv.pth
# ./.venv/lib/python3.11/site-packages/setuptools-69.5.1.virtualenv
# ./.venv/lib/python3.11/site-packages/six.py
# ./.venv/lib/python3.11/site-packages/nest_asyncio.py
# ./.venv/lib/python3.11/site-packages/typing_extensions.py
# ./.venv/lib/python3.11/site-packages/jupyter.py
# ./.venv/lib/python3.11/site-packages/pip-24.0.virtualenv
# ./.venv/lib/python3.11/site-packages/flatbuffers-24.3.25.dist-info/RECORD
# ./.venv/lib/python3.11/site-packages/flatbuffers-24.3.25.dist-info/WHEEL
# ./.venv/lib/python3.11/site-packages/flatbuffers-24.3.25.dist-info/top_level.txt
# ./.venv/lib/python3.11/site-packages/flatbuffers-24.3.25.dist-info/INSTALLER
# ./.venv/lib/python3.11/site-packages/flatbuffers-24.3.25.dist-info/METADATA
# ./.venv/lib/python3.11/site-packages/h5py-3.11.0.dist-info/RECORD
# ./.venv/lib/python3.11/site-packages/h5py-3.11.0.dist-info/LICENSE
# ./.venv/lib/python3.11/site-packages/h5py-3.11.0.dist-info/WHEEL
# ./.venv/lib/python3.11/site-packages/h5py-3.11.0.dist-info/top_level.txt
# ./.venv/lib/python3.11/site-packages/h5py-3.11.0.dist-info/INSTALLER
# ./.venv/lib/python3.11/site-packages/h5py-3.11.0.dist-info/METADATA
# ./.venv/lib/python3.11/site-packages/appnope/_nope.py
# ./.venv/lib/python3.11/site-packages/appnope/__init__.py
# ./.venv/lib/python3.11/site-packages/appnope/_dummy.py
# ./.venv/lib/python3.11/site-packages/appnope/__pycache__/_nope.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/appnope/__pycache__/_dummy.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/appnope/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/mdurl/_decode.py
# ./.venv/lib/python3.11/site-packages/mdurl/_url.py
# ./.venv/lib/python3.11/site-packages/mdurl/__init__.py
# ./.venv/lib/python3.11/site-packages/mdurl/_format.py
# ./.venv/lib/python3.11/site-packages/mdurl/_parse.py
# ./.venv/lib/python3.11/site-packages/mdurl/py.typed
# ./.venv/lib/python3.11/site-packages/mdurl/_encode.py
# ./.venv/lib/python3.11/site-packages/mdurl/__pycache__/_encode.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/mdurl/__pycache__/_decode.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/mdurl/__pycache__/_format.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/mdurl/__pycache__/_url.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/mdurl/__pycache__/_parse.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/mdurl/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/packaging/tags.py
# ./.venv/lib/python3.11/site-packages/packaging/_musllinux.py
# ./.venv/lib/python3.11/site-packages/packaging/metadata.py
# ./.venv/lib/python3.11/site-packages/packaging/version.py
# ./.venv/lib/python3.11/site-packages/packaging/__init__.py
# ./.venv/lib/python3.11/site-packages/packaging/_parser.py
# ./.venv/lib/python3.11/site-packages/packaging/utils.py
# ./.venv/lib/python3.11/site-packages/packaging/requirements.py
# ./.venv/lib/python3.11/site-packages/packaging/_structures.py
# ./.venv/lib/python3.11/site-packages/packaging/markers.py
# ./.venv/lib/python3.11/site-packages/packaging/py.typed
# ./.venv/lib/python3.11/site-packages/packaging/_manylinux.py
# ./.venv/lib/python3.11/site-packages/packaging/_tokenizer.py
# ./.venv/lib/python3.11/site-packages/packaging/specifiers.py
# ./.venv/lib/python3.11/site-packages/packaging/_elffile.py
# ./.venv/lib/python3.11/site-packages/packaging/__pycache__/markers.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/packaging/__pycache__/requirements.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/packaging/__pycache__/_musllinux.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/packaging/__pycache__/tags.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/packaging/__pycache__/utils.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/packaging/__pycache__/metadata.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/packaging/__pycache__/_tokenizer.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/packaging/__pycache__/_manylinux.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/packaging/__pycache__/_parser.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/packaging/__pycache__/_elffile.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/packaging/__pycache__/version.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/packaging/__pycache__/specifiers.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/packaging/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/packaging/__pycache__/_structures.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/sharing.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/paths.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/_version.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/__init__.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/path_random.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/parser.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/blas.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/contract.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/helpers.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/backends/dispatch.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/backends/object_arrays.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/backends/__init__.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/backends/tensorflow.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/backends/jax.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/backends/cupy.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/backends/theano.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/backends/torch.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/backends/__pycache__/theano.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/backends/__pycache__/dispatch.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/backends/__pycache__/jax.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/backends/__pycache__/tensorflow.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/backends/__pycache__/object_arrays.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/backends/__pycache__/cupy.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/backends/__pycache__/torch.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/backends/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/tests/test_input.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/tests/test_sharing.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/tests/__init__.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/tests/test_contract.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/tests/test_blas.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/tests/test_paths.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/tests/test_edge_cases.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/tests/test_backends.py
# ./.venv/lib/python3.11/site-packages/opt_einsum/tests/__pycache__/test_input.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/tests/__pycache__/test_paths.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/tests/__pycache__/test_contract.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/tests/__pycache__/test_blas.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/tests/__pycache__/test_backends.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/tests/__pycache__/test_edge_cases.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/tests/__pycache__/test_sharing.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/tests/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/__pycache__/path_random.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/__pycache__/helpers.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/__pycache__/sharing.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/__pycache__/_version.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/__pycache__/paths.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/__pycache__/blas.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/__pycache__/parser.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/__pycache__/contract.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/opt_einsum/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/activations/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/activations/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/tree/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/tree/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/metrics/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/metrics/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/losses/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/losses/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/layers/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/layers/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/constraints/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/constraints/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/config/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/config/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/callbacks/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/callbacks/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/quantizers/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/quantizers/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/datasets/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/datasets/mnist/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/datasets/mnist/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/datasets/boston_housing/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/datasets/boston_housing/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/datasets/fashion_mnist/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/datasets/fashion_mnist/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/datasets/reuters/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/datasets/reuters/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/datasets/cifar100/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/datasets/cifar100/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/datasets/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/datasets/imdb/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/datasets/imdb/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/datasets/california_housing/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/datasets/california_housing/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/datasets/cifar10/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/datasets/cifar10/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/distribution/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/distribution/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/mixed_precision/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/mixed_precision/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/legacy/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/legacy/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/legacy/saving/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/legacy/saving/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/utils/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/utils/legacy/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/utils/legacy/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/utils/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/backend/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/backend/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/models/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/models/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/optimizers/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/optimizers/legacy/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/optimizers/legacy/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/optimizers/schedules/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/optimizers/schedules/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/optimizers/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/regularizers/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/regularizers/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/dtype_policies/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/dtype_policies/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/resnet50/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/resnet50/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/densenet/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/densenet/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/mobilenet/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/mobilenet/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/convnext/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/convnext/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/imagenet_utils/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/imagenet_utils/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/resnet/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/resnet/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/efficientnet_v2/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/efficientnet_v2/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/inception_v3/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/inception_v3/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/efficientnet/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/efficientnet/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/vgg16/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/vgg16/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/mobilenet_v2/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/mobilenet_v2/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/vgg19/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/vgg19/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/mobilenet_v3/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/mobilenet_v3/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/resnet_v2/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/resnet_v2/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/xception/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/xception/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/nasnet/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/nasnet/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/inception_resnet_v2/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/applications/inception_resnet_v2/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/ops/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/ops/linalg/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/ops/linalg/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/ops/nn/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/ops/nn/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/ops/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/ops/numpy/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/ops/numpy/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/ops/image/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/ops/image/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/preprocessing/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/preprocessing/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/preprocessing/image/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/preprocessing/image/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/preprocessing/text/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/preprocessing/text/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/preprocessing/sequence/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/preprocessing/sequence/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/saving/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/saving/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/export/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/export/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/random/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/random/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/initializers/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/keras/initializers/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/_tf_keras/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/activations/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/activations/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/tree/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/tree/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/metrics/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/metrics/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/losses/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/losses/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/layers/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/layers/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/constraints/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/constraints/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/config/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/config/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/callbacks/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/callbacks/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/quantizers/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/quantizers/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/datasets/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/datasets/mnist/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/datasets/mnist/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/datasets/boston_housing/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/datasets/boston_housing/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/datasets/fashion_mnist/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/datasets/fashion_mnist/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/datasets/reuters/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/datasets/reuters/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/datasets/cifar100/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/datasets/cifar100/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/datasets/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/datasets/imdb/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/datasets/imdb/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/datasets/california_housing/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/datasets/california_housing/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/datasets/cifar10/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/datasets/cifar10/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/distribution/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/distribution/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/mixed_precision/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/mixed_precision/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/legacy/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/legacy/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/legacy/saving/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/legacy/saving/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/utils/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/utils/legacy/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/utils/legacy/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/utils/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/backend/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/backend/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/models/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/models/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/optimizers/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/optimizers/legacy/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/optimizers/legacy/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/optimizers/schedules/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/optimizers/schedules/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/optimizers/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/regularizers/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/regularizers/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/dtype_policies/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/dtype_policies/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/applications/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/applications/resnet50/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/applications/resnet50/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/applications/densenet/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/applications/densenet/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/applications/mobilenet/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/applications/mobilenet/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/applications/convnext/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/applications/convnext/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/applications/imagenet_utils/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/applications/imagenet_utils/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/applications/resnet/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/applications/resnet/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/applications/efficientnet_v2/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/applications/efficientnet_v2/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/applications/inception_v3/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/applications/inception_v3/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/applications/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/applications/efficientnet/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/applications/efficientnet/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/applications/vgg16/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/applications/vgg16/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/applications/mobilenet_v2/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/applications/mobilenet_v2/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/applications/vgg19/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/applications/vgg19/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/applications/mobilenet_v3/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/applications/mobilenet_v3/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/applications/resnet_v2/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/applications/resnet_v2/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/applications/xception/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/applications/xception/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/applications/nasnet/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/applications/nasnet/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/applications/inception_resnet_v2/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/applications/inception_resnet_v2/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/ops/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/ops/linalg/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/ops/linalg/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/ops/nn/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/ops/nn/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/ops/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/ops/numpy/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/ops/numpy/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/ops/image/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/ops/image/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/preprocessing/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/preprocessing/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/preprocessing/image/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/preprocessing/image/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/preprocessing/sequence/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/preprocessing/sequence/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/saving/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/saving/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/export/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/export/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/random/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/random/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/api/initializers/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/api/initializers/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/version.py
# ./.venv/lib/python3.11/site-packages/keras/src/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/src/api_export.py
# ./.venv/lib/python3.11/site-packages/keras/src/activations/activations.py
# ./.venv/lib/python3.11/site-packages/keras/src/activations/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/src/activations/__pycache__/activations.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/activations/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/tree/dmtree_impl.py
# ./.venv/lib/python3.11/site-packages/keras/src/tree/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/src/tree/optree_impl.py
# ./.venv/lib/python3.11/site-packages/keras/src/tree/tree_api.py
# ./.venv/lib/python3.11/site-packages/keras/src/tree/__pycache__/dmtree_impl.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/tree/__pycache__/tree_api.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/tree/__pycache__/optree_impl.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/tree/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/hinge_metrics.py
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/reduction_metrics.py
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/f_score_metrics.py
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/probabilistic_metrics.py
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/confusion_metrics.py
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/regression_metrics.py
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/metric.py
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/metrics_utils.py
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/iou_metrics.py
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/accuracy_metrics.py
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/__pycache__/reduction_metrics.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/__pycache__/accuracy_metrics.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/__pycache__/iou_metrics.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/__pycache__/metric.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/__pycache__/f_score_metrics.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/__pycache__/regression_metrics.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/__pycache__/hinge_metrics.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/__pycache__/confusion_metrics.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/__pycache__/metrics_utils.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/__pycache__/probabilistic_metrics.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/metrics/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/losses/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/src/losses/loss.py
# ./.venv/lib/python3.11/site-packages/keras/src/losses/losses.py
# ./.venv/lib/python3.11/site-packages/keras/src/losses/__pycache__/loss.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/losses/__pycache__/losses.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/losses/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/input_spec.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/layer.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/activations/leaky_relu.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/activations/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/activations/activation.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/activations/prelu.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/activations/relu.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/activations/elu.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/activations/softmax.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/activations/__pycache__/leaky_relu.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/activations/__pycache__/relu.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/activations/__pycache__/softmax.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/activations/__pycache__/activation.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/activations/__pycache__/prelu.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/activations/__pycache__/elu.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/activations/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/attention/grouped_query_attention.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/attention/attention.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/attention/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/attention/multi_head_attention.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/attention/additive_attention.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/attention/__pycache__/multi_head_attention.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/attention/__pycache__/attention.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/attention/__pycache__/additive_attention.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/attention/__pycache__/grouped_query_attention.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/attention/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/up_sampling3d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/up_sampling2d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/permute.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/up_sampling1d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/flatten.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/repeat_vector.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/cropping1d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/reshape.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/cropping3d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/cropping2d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/zero_padding3d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/zero_padding2d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/zero_padding1d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/__pycache__/cropping3d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/__pycache__/reshape.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/__pycache__/zero_padding1d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/__pycache__/flatten.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/__pycache__/cropping2d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/__pycache__/repeat_vector.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/__pycache__/up_sampling1d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/__pycache__/zero_padding3d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/__pycache__/cropping1d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/__pycache__/up_sampling2d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/__pycache__/permute.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/__pycache__/zero_padding2d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/__pycache__/up_sampling3d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/max_pooling1d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/max_pooling3d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/max_pooling2d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/global_max_pooling1d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/average_pooling1d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/global_max_pooling2d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/average_pooling3d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/average_pooling2d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/global_max_pooling3d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/global_average_pooling2d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/global_average_pooling3d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/base_global_pooling.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/global_average_pooling1d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/base_pooling.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/__pycache__/average_pooling2d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/__pycache__/max_pooling1d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/__pycache__/global_average_pooling2d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/__pycache__/global_max_pooling2d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/__pycache__/average_pooling3d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/__pycache__/global_max_pooling3d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/__pycache__/global_average_pooling3d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/__pycache__/max_pooling3d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/__pycache__/max_pooling2d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/__pycache__/global_average_pooling1d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/__pycache__/global_max_pooling1d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/__pycache__/average_pooling1d.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/__pycache__/base_global_pooling.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/__pycache__/base_pooling.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/pooling/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/core/wrapper.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/core/embedding.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/core/dense.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/core/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/core/masking.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/core/lambda_layer.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/core/input_layer.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/core/einsum_dense.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/core/identity.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/core/__pycache__/masking.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/core/__pycache__/lambda_layer.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/core/__pycache__/embedding.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/core/__pycache__/wrapper.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/core/__pycache__/einsum_dense.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/core/__pycache__/identity.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/core/__pycache__/input_layer.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/core/__pycache__/dense.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/core/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/normalization/batch_normalization.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/normalization/layer_normalization.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/normalization/__init__.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/normalization/unit_normalization.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/normalization/group_normalization.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/normalization/spectral_normalization.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/normalization/__pycache__/batch_normalization.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/normalization/__pycache__/layer_normalization.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/normalization/__pycache__/group_normalization.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/normalization/__pycache__/unit_normalization.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/normalization/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/normalization/__pycache__/spectral_normalization.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/keras/src/layers/convolutional/base_depthwise_conv.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/convolutional/depthwise_conv2d.py
# ./.venv/lib/python3.11/site-packages/keras/src/layers/convolutional/depthwise_conv1d.py
# ...
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslib.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/__init__.py
# ./.venv/lib/python3.11/site-packages/pandas/_libs/ops.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/internals.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/sparse.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/arrays.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/parsers.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/sas.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/reshape.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/sas.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/interval.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/json.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/sparse.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/index.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/join.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/testing.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/lib.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/testing.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/internals.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/pandas_parser.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/join.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/hashing.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/byteswap.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/properties.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/hashtable.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/ops_dispatch.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/byteswap.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/pandas_datetime.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/writers.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/interval.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/arrays.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/properties.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/_libs/window/indexers.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/window/aggregations.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/window/__init__.py
# ./.venv/lib/python3.11/site-packages/pandas/_libs/window/indexers.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/window/aggregations.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/window/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/strptime.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/offsets.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/dtypes.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/vectorized.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/tzconversion.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/base.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/parsing.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/timedeltas.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/parsing.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/timestamps.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/dtypes.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/timezones.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/np_datetime.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/vectorized.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/strptime.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/np_datetime.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/period.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/timestamps.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/__init__.py
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/timezones.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/period.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/conversion.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/nattype.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/fields.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/ccalendar.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/tzconversion.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/fields.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/nattype.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/conversion.pyi
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/offsets.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/timedeltas.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/ccalendar.cpython-311-darwin.so
# ./.venv/lib/python3.11/site-packages/pandas/_libs/tslibs/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/plotting/__init__.py
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_core.py
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_misc.py
# ./.venv/lib/python3.11/site-packages/pandas/plotting/__pycache__/_core.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/plotting/__pycache__/_misc.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/plotting/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/misc.py
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/hist.py
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/boxplot.py
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/style.py
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/tools.py
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/converter.py
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__init__.py
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/groupby.py
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/timeseries.py
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__pycache__/groupby.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__pycache__/core.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__pycache__/converter.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__pycache__/style.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__pycache__/boxplot.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__pycache__/misc.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__pycache__/timeseries.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__pycache__/tools.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__pycache__/hist.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/arrays/__init__.py
# ./.venv/lib/python3.11/site-packages/pandas/arrays/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/api/__init__.py
# ./.venv/lib/python3.11/site-packages/pandas/api/indexers/__init__.py
# ./.venv/lib/python3.11/site-packages/pandas/api/indexers/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/api/types/__init__.py
# ./.venv/lib/python3.11/site-packages/pandas/api/types/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/api/interchange/__init__.py
# ./.venv/lib/python3.11/site-packages/pandas/api/interchange/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/api/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/api/extensions/__init__.py
# ./.venv/lib/python3.11/site-packages/pandas/api/extensions/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/api/typing/__init__.py
# ./.venv/lib/python3.11/site-packages/pandas/api/typing/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/errors/__init__.py
# ./.venv/lib/python3.11/site-packages/pandas/errors/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/_config/config.py
# ./.venv/lib/python3.11/site-packages/pandas/_config/__init__.py
# ./.venv/lib/python3.11/site-packages/pandas/_config/display.py
# ./.venv/lib/python3.11/site-packages/pandas/_config/localization.py
# ./.venv/lib/python3.11/site-packages/pandas/_config/dates.py
# ./.venv/lib/python3.11/site-packages/pandas/_config/__pycache__/display.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/_config/__pycache__/config.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/_config/__pycache__/dates.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/_config/__pycache__/localization.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/pandas/_config/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/dateutil/relativedelta.py
# ./.venv/lib/python3.11/site-packages/dateutil/_version.py
# ./.venv/lib/python3.11/site-packages/dateutil/_common.py
# ./.venv/lib/python3.11/site-packages/dateutil/__init__.py
# ./.venv/lib/python3.11/site-packages/dateutil/tzwin.py
# ./.venv/lib/python3.11/site-packages/dateutil/rrule.py
# ./.venv/lib/python3.11/site-packages/dateutil/utils.py
# ./.venv/lib/python3.11/site-packages/dateutil/easter.py
# ./.venv/lib/python3.11/site-packages/dateutil/zoneinfo/dateutil-zoneinfo.tar.gz
# ./.venv/lib/python3.11/site-packages/dateutil/zoneinfo/__init__.py
# ./.venv/lib/python3.11/site-packages/dateutil/zoneinfo/rebuild.py
# ./.venv/lib/python3.11/site-packages/dateutil/zoneinfo/__pycache__/rebuild.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/dateutil/zoneinfo/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/dateutil/__pycache__/tzwin.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/dateutil/__pycache__/easter.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/dateutil/__pycache__/_common.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/dateutil/__pycache__/utils.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/dateutil/__pycache__/relativedelta.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/dateutil/__pycache__/_version.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/dateutil/__pycache__/rrule.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/dateutil/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/dateutil/parser/isoparser.py
# ./.venv/lib/python3.11/site-packages/dateutil/parser/__init__.py
# ./.venv/lib/python3.11/site-packages/dateutil/parser/_parser.py
# ./.venv/lib/python3.11/site-packages/dateutil/parser/__pycache__/isoparser.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/dateutil/parser/__pycache__/_parser.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/dateutil/parser/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/dateutil/tz/_factories.py
# ./.venv/lib/python3.11/site-packages/dateutil/tz/tz.py
# ./.venv/lib/python3.11/site-packages/dateutil/tz/_common.py
# ./.venv/lib/python3.11/site-packages/dateutil/tz/__init__.py
# ./.venv/lib/python3.11/site-packages/dateutil/tz/win.py
# ./.venv/lib/python3.11/site-packages/dateutil/tz/__pycache__/win.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/dateutil/tz/__pycache__/_common.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/dateutil/tz/__pycache__/_factories.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/dateutil/tz/__pycache__/tz.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/dateutil/tz/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/executing-2.0.1.dist-info/RECORD
# ./.venv/lib/python3.11/site-packages/executing-2.0.1.dist-info/WHEEL
# ./.venv/lib/python3.11/site-packages/executing-2.0.1.dist-info/top_level.txt
# ./.venv/lib/python3.11/site-packages/executing-2.0.1.dist-info/LICENSE.txt
# ./.venv/lib/python3.11/site-packages/executing-2.0.1.dist-info/INSTALLER
# ./.venv/lib/python3.11/site-packages/executing-2.0.1.dist-info/METADATA
# ./.venv/lib/python3.11/site-packages/platformdirs/macos.py
# ./.venv/lib/python3.11/site-packages/platformdirs/unix.py
# ./.venv/lib/python3.11/site-packages/platformdirs/version.py
# ./.venv/lib/python3.11/site-packages/platformdirs/__init__.py
# ./.venv/lib/python3.11/site-packages/platformdirs/api.py
# ./.venv/lib/python3.11/site-packages/platformdirs/android.py
# ./.venv/lib/python3.11/site-packages/platformdirs/py.typed
# ./.venv/lib/python3.11/site-packages/platformdirs/windows.py
# ./.venv/lib/python3.11/site-packages/platformdirs/__main__.py
# ./.venv/lib/python3.11/site-packages/platformdirs/__pycache__/api.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/platformdirs/__pycache__/android.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/platformdirs/__pycache__/windows.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/platformdirs/__pycache__/macos.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/platformdirs/__pycache__/unix.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/platformdirs/__pycache__/version.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/platformdirs/__pycache__/__init__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/platformdirs/__pycache__/__main__.cpython-311.pyc
# ./.venv/lib/python3.11/site-packages/tornado-6.4.dist-info/RECORD
# ./.venv/lib/python3.11/site-packages/tornado-6.4.dist-info/LICENSE
# ./.venv/lib/python3.11/site-packages/tornado-6.4.dist-info/WHEEL
# ./.venv/lib/python3.11/site-packages/tornado-6.4.dist-info/top_level.txt
# ./.venv/lib/python3.11/site-packages/tornado-6.4.dist-info/INSTALLER
# ./.venv/lib/python3.11/site-packages/tornado-6.4.dist-info/METADATA
# ./.venv/lib/python3.11/site-packages/wrapt-1.16.0.dist-info/RECORD
# ./.venv/lib/python3.11/site-packages/wrapt-1.16.0.dist-info/LICENSE
# ./.venv/lib/python3.11/site-packages/wrapt-1.16.0.dist-info/WHEEL
# ./.venv/lib/python3.11/site-packages/wrapt-1.16.0.dist-info/top_level.txt
# ./.venv/lib/python3.11/site-packages/wrapt-1.16.0.dist-info/INSTALLER
# ./.venv/lib/python3.11/site-packages/wrapt-1.16.0.dist-info/METADATA
# ./.venv/share/man/man1/ipython.1
# ./.venv/share/man/man1/ttx.1
# ./.venv/share/jupyter/kernels/python3/kernel.json
# ./.venv/share/jupyter/kernels/python3/logo-64x64.png
# ./.venv/share/jupyter/kernels/python3/logo-32x32.png
# ./.venv/share/jupyter/kernels/python3/logo-svg.svg
# ./.git/config
# ./.git/HEAD
# ./.git/description
# ./.git/index
# ./.git/packed-refs
# ./.git/FETCH_HEAD
# ./.git/sourcetreeconfig
# ./.git/objects/pack/pack-2adadc0bdb31da4974dda73d428cd3593acd5a72.idx
# ./.git/objects/pack/pack-2adadc0bdb31da4974dda73d428cd3593acd5a72.pack
# ./.git/info/exclude
# ./.git/logs/HEAD
# ./.git/logs/refs/heads/main
# ./.git/logs/refs/remotes/origin/HEAD
# ./.git/hooks/commit-msg.sample
# ./.git/hooks/pre-rebase.sample
# ./.git/hooks/pre-commit.sample
# ./.git/hooks/applypatch-msg.sample
# ./.git/hooks/fsmonitor-watchman.sample
# ./.git/hooks/pre-receive.sample
# ./.git/hooks/prepare-commit-msg.sample
# ./.git/hooks/post-update.sample
# ./.git/hooks/pre-merge-commit.sample
# ./.git/hooks/pre-applypatch.sample
# ./.git/hooks/pre-push.sample
# ./.git/hooks/update.sample
# ./.git/hooks/push-to-checkout.sample
# ./.git/refs/heads/main
# ./.git/refs/remotes/origin/HEAD

# %%
tsmc =  pd.read_csv('./2010.1.1~2024.4.1/2330.TW.csv', header=0)
tsmc = tsmc.dropna(axis=0, thresh=tsmc.shape[1])
tsmc.shape[1]
# Out:
# 7

# %%
tsm = pd.read_csv('./2010.1.1~2024.4.1/TSM(ADR).csv', header=0)
tsm = tsm.dropna(axis=0, thresh=tsm.shape[1])
tsmc.shape[1]
# Out:
# 7

# %%
sox = pd.read_csv('./^SOX(費城半導體).csv', header=0)

# %% [markdown]
# <a id="2"></a> <br>
# ## Descriptive Analysis

# %%
data.head()
# Out:
#        date symbol       open      close        low       high      volume
# 0  2010/1/4   TSMC  65.000000  64.900002  64.000000  65.000000  39407000.0
# 1  2010/1/5   TSMC  65.000000  64.500000  63.900002  65.099998  37138000.0
# 2  2010/1/6   TSMC  64.500000  64.900002  63.700001  64.900002  49261000.0
# 3  2010/1/7   TSMC  64.900002  64.199997  64.199997  65.000000  42134000.0
# 4  2010/1/8   TSMC  63.500000  64.000000  63.500000  64.300003  46076000.0

# %%
print(data.columns)
print(data.shape)
# Out:
# Index(['date', 'symbol', 'open', 'close', 'low', 'high', 'volume'], dtype='object')
# (3485, 7)

# %%
data.iloc[:, 2:-1].describe()
# Out:
#               open        close          low         high
# count  3485.000000  3485.000000  3485.000000  3485.000000
# mean    255.528666   255.461865   253.498393   257.286485
# std     188.379134   188.252477   186.898072   189.588331
# min      57.599998    57.200001    57.000000    57.900002
# 25%     103.500000   103.500000   102.500000   104.500000
# 50%     187.000000   187.000000   186.000000   188.000000
# 75%     418.500000   416.000000   409.000000   423.500000
# max     795.000000   785.000000   779.000000   796.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3485 entries, 0 to 3489
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3485 non-null   object
#  1   symbol  3485 non-null   object
#  2   open    3485 non-null   float64
#  3   close   3485 non-null   float64
#  4   low     3485 non-null   float64
#  5   high    3485 non-null   float64
#  6   volume  3485 non-null   float64
# dtypes: float64(5), object(2)
# memory usage: 217.8+ KB

# %% [markdown]
# <a id="21"></a> <br>
# ## Number of unique stock symbols

# %%
print(len(data['symbol'].unique()))
symbols = data['symbol'].unique()
# Out:
# 1

# %%
data['symbol'].describe()
# Out:
# count     3485
# unique       1
# top       TSMC
# freq      3485
# Name: symbol, dtype: object

# %% [markdown]
# <a id="22"></a> <br>
# ## Choosing a Random Stock Symbol

# %%
# random.seed(42)  #explain!
choosen_symbol = random.choice(symbols)
print(choosen_symbol)
# Out:
# TSMC

# %%
data_prices = data[data['symbol'] == choosen_symbol].reset_index(drop = True)
data_prices.iloc[:10, :]
# Out:
#         date symbol       open      close        low       high      volume
# 0   2010/1/4   TSMC  65.000000  64.900002  64.000000  65.000000  39407000.0
# 1   2010/1/5   TSMC  65.000000  64.500000  63.900002  65.099998  37138000.0
# 2   2010/1/6   TSMC  64.500000  64.900002  63.700001  64.900002  49261000.0
# 3   2010/1/7   TSMC  64.900002  64.199997  64.199997  65.000000  42134000.0
# 4   2010/1/8   TSMC  63.500000  64.000000  63.500000  64.300003  46076000.0
# 5  2010/1/11   TSMC  64.000000  64.500000  63.500000  64.900002  36799000.0
# 6  2010/1/12   TSMC  64.400002  63.599998  63.299999  64.400002  49853000.0
# 7  2010/1/13   TSMC  63.000000  62.799999  62.599998  63.099998  47976000.0
# 8  2010/1/14   TSMC  63.599998  63.200001  63.000000  63.599998  36149000.0
# 9  2010/1/15   TSMC  62.900002  63.500000  62.799999  63.500000  47852000.0

# %%
data_prices = data_prices.drop(['date', 'symbol'], axis=1)

# %% [markdown]
# <a id="23"></a> <br>
# ## plotting Price through Time
#
# While the first big plot shows opening, closing, low, and high price altogether, the following four plots show each attribute separately. It may seem that all of the mentioned prices are the same, but as it is clear in the first big plot, they have a slight difference with each other.

# %%
plt.figure(figsize=(16,8), dpi= 100, facecolor='w', edgecolor='k')

plt.plot(data_prices['open'], color='red', label = 'Opening Price')
plt.plot(data_prices['close'], color='green', label = 'Closing Price')
plt.plot(data_prices['low'], color='black', label = 'Low Price')
plt.plot(data_prices['high'], color='blue', label = 'High Price')
plt.legend(loc='best')

plt.subplots(2, 2, figsize = (20, 10))

ax1 = plt.subplot(2, 2, 1)
plt.plot(data_prices['open'], color='red')
plt.xlabel('Date')
plt.ylabel('Opening Price')

ax2 = plt.subplot(2, 2, 2)
plt.plot(data_prices['close'], color='green')
plt.xlabel('Date')
plt.ylabel('Closing Price')

ax3 = plt.subplot(2, 2, 3)
plt.plot(data_prices['low'], color='black')
plt.xlabel('Date')
plt.ylabel('Low Price')

ax4 = plt.subplot(2, 2, 4)
plt.plot(data_prices['high'], color='blue')
plt.xlabel('Date')
plt.ylabel('High Price')

plt.legend(loc='best')

plt.figure(figsize=(20, 10))
plt.plot(data_prices["volume"], color="purple")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.legend(loc="best")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import numpy as np

dates = data_prices.index
volumes = data_prices['volume']
high_prices = data_prices['high']

color_map = plt.cm.get_cmap('coolwarm') 
norm = plt.Normalize(volumes.min(), volumes.max())

fig, ax1 = plt.subplots(figsize=(16, 8))

bar_colors = color_map(norm(volumes))
bars = ax1.bar(dates, volumes, color=bar_colors, label='Volume', alpha=0.7)


sm = plt.cm.ScalarMappable(cmap=color_map, norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm)
cbar.set_label('Volume')

ax2 = ax1.twinx()
ax2.plot(dates, high_prices, color='blue', label='High Price')


ax1.set_xlabel('Date')
ax1.set_ylabel('Volume', color='purple')
ax2.set_ylabel('High Price', color='blue')
plt.title('Volume and High Price Chart')


ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15120\3608199628.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   color_map = plt.cm.get_cmap('coolwarm')  # 你可以选择任何喜欢的颜色映射
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15120\3608199628.py:22: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %% [markdown]
# We choose the opening price and volume as two attributes to consider in our model.

# %%
# data_prices = data_prices.drop(['close', 'low', 'high'], axis=1)

# %% [markdown]
# <a id="24"></a> <br>
# ## Fearure Scaling

# %%
# Feature Scaling
sc = MinMaxScaler(feature_range=(0, 1))
data_prices_scaled = sc.fit_transform(data_prices)

# %%
data_prices_scaled.shape
# Out:
# (3485, 5)

# %% [markdown]
# <a id="25"></a> <br>
# ## Creating LSTM input data
#
# In order to use LSTM, our input and output data should have a specific shape. It was a bit complicated for me when I was first introduced to LSTM, but I found [this](https://medium.com/@shivajbd/understanding-input-and-output-shape-in-lstm-keras-c501ee95c65e) comprehensive article to fully understand what was going on. In a nutshell, the input and output data in an LSTM model is a three-dimensional array where the first dimension represents **the number of samples (or batch size)** like the number of rows of data in a two-dimensional setting, the second dimension stands for **time steps** which indicates the amount of time that we want to go back through time, and the third dimension shows **the number of features (or input dimension)** that we want to include in the model for every element in our batch. So, it is like [number_of_samples, time_steps, input_dim]. The below image is retrieved from the mentioned article and could be a good illustration of the LSTM input and output data shape.
# ![](https://miro.medium.com/max/665/1*AQKRJsRdWx2HZ85H1yWoKw.png)

# %% [markdown]
# Sometimes we prefer to choose the validation set by ourselves. In this case, in the below code, you can pass a value in the range of (0, 1) for the validation_split_percentage when you are calling the create_data function, and use the below code to fit the model:
#
# - model.fit(train_X, train_y, validation_data=(val_x, val_y))  # manually splitting
#
# In my case, I rathered to use the built-in parameter (validation_split) in the fit method of the Keras library.  It considers a fraction of the training data as the validation set to evaluate loss and metrics at the end of each epoch as follow:
#
# - model.fit(train_X, train_y, validation_split=0.3)  # automatically splitting

# %% [markdown]
# Here, at each point of the time, we will consider price and volume as our attributes in input_dim, and 25 days as our time_steps.

# %%
# Creating a data structure (it does not work when you have only one feature)
def create_data(df, n_future, n_past, train_test_split_percentage, validation_split_percentage):
    n_feature = df.shape[1]
    x_data, y_data = [], []
    
    for i in range(n_past, len(df) - n_future + 1):
        x_data.append(df[i - n_past:i, 0:n_feature])
        y_data.append(df[i + n_future - 1:i + n_future, 0])
    
    split_training_test_starting_point = int(round(train_test_split_percentage*len(x_data)))
    split_train_validation_starting_point = int(round(split_training_test_starting_point*(1-validation_split_percentage)))
    
    x_train = x_data[:split_train_validation_starting_point]
    y_train = y_data[:split_train_validation_starting_point]
    
    # if you want to choose the validation set by yourself, uncomment the below code.
    x_val = x_data[split_train_validation_starting_point:split_training_test_starting_point]
    y_val =  y_data[split_train_validation_starting_point:split_training_test_starting_point]                                             
    
    x_test = x_data[split_training_test_starting_point:]
    y_test = y_data[split_training_test_starting_point:]
    
    return np.array(x_train), np.array(x_test), np.array(x_val), np.array(y_train), np.array(y_test), np.array(y_val)

# %%
# Number of days you want to predict into the future
# Number of past days you want to use to predict the future

X_train, X_test, X_val, y_train, y_test, y_val = create_data(data_prices_scaled, n_future=5, n_past=5, train_test_split_percentage=0.8,
                                               validation_split_percentage = 0)

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)

print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (2781, 5, 5)
# (0,)
# (695, 5, 5)
# (2781, 1)
# (0,)
# (695, 1)

# %% [markdown]
# <a id="3"></a> <br>
# ## Train LSTM Model

# %%
# ------------------LSTM-----------------------
regressor = Sequential()
regressor.add(LSTM(units=16, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=16, return_sequences=False))
regressor.add(Dropout(0.2))
regressor.add(Dense(units=5, activation='linear'))
regressor.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])

regressor.summary()
# Out:
# /Users/patten/my_files/大學課業/大三/資料探勘/project/original/.venv/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_20 (LSTM)                  │ (None, 5, 16)          │         1,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 5, 16)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_21 (LSTM)                  │ (None, 16)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_21 (Dropout)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 5)              │            85 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,605 (14.08 KB)
#  Trainable params: 3,605 (14.08 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
mc = ModelCheckpoint('best_model.keras', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# fit model
history = regressor.fit(X_train, y_train, validation_split=0.3, epochs=40, batch_size=64, callbacks=[es])
# Out:
# Epoch 1/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0073 - root_mean_squared_error: 0.0852 - val_loss: 0.0578 - val_root_mean_squared_error: 0.2404
# Epoch 2/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0027 - root_mean_squared_error: 0.0521 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1298
# Epoch 3/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - root_mean_squared_error: 0.0342 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0546
# Epoch 4/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.2533e-04 - root_mean_squared_error: 0.0287 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0461
# Epoch 5/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.9828e-04 - root_mean_squared_error: 0.0245 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0422
# Epoch 6/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.9932e-04 - root_mean_squared_error: 0.0245 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0446
# Epoch 7/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.6468e-04 - root_mean_squared_error: 0.0215 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0439
# Epoch 8/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4890e-04 - root_mean_squared_error: 0.0212 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0403
# Epoch 9/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.1951e-04 - root_mean_squared_error: 0.0205 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0427
# Epoch 10/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6466e-04 - root_mean_squared_error: 0.0191 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0447
# Epoch 11/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.1802e-04 - root_mean_squared_error: 0.0178 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0524
# Epoch 12/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.1121e-04 - root_mean_squared_error: 0.0176 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0553
# Epoch 13/40
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.7549e-04 - root_mean_squared_error: 0.0166 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0540
# Epoch 13: early stopping

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'root_mean_squared_error', 'val_loss', 'val_root_mean_squared_error'])

# %%
fig = plt.figure(figsize=(20,7))
fig.add_subplot(121)

# Accuracy
plt.plot(history.epoch, history.history['root_mean_squared_error'], label = "rmse")
plt.plot(history.epoch, history.history['val_root_mean_squared_error'], label = "val_rmse")

plt.title("RMSE", fontsize=18)
plt.xlabel("Epochs", fontsize=15)
plt.ylabel("RMSE", fontsize=15)
plt.grid(alpha=0.3)
plt.legend()


#Adding Subplot 1 (For Loss)
fig.add_subplot(122)

plt.plot(history.epoch, history.history['loss'], label="loss")
plt.plot(history.epoch, history.history['val_loss'], label="val_loss")

plt.title("Loss", fontsize=18)
plt.xlabel("Epochs", fontsize=15)
plt.ylabel("Loss", fontsize=15)
plt.grid(alpha=0.3)
plt.legend()

plt.show()

# %%
results = regressor.evaluate(X_test, y_test)
print("test loss, test acc:", np.round(results, 4))
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0145 - root_mean_squared_error: 0.1198
# test loss, test acc: [0.0146 0.121 ]

# %% [markdown]
# <a id="4"></a> <br>
# ## Hyperparameter Tunning

# %% [markdown]
# We have two important terms in machine learning referred to as **model parameter** and **model hyperparamer**. So, first of all, what is a hyperparameter, and what is a parameter? Based on [here](https://www.datacamp.com/community/tutorials/parameter-optimization-machine-learning-models),
#
# - A model **model hyperparameter** is a configuration that is external to the model and whose value cannot be estimated from the data and a **model parameter** is a configuration variable that is internal to the model and whose value can be estimated from the given data.
#
# In the other words, a hyperparameter is used to construct the structure of the model and cannot be learned from the data and its value is set before the learning process begins. Therefore, hyperparameters are like the settings of an algorithm that can be adjusted to optimize performance and prevent overfitting. This is exactly what we do in the hyperparameter tuning. We try to choose a set of optimal hyperparameters for a learning algorithm to enhance the performance of the model. There are two frequently used methods to perform hyperparameter tunning called 1)Grid Search and 2)Random Search. In this notebook, I have used the former one because of its simplicity to implement and at the same time, its powerful performance. More information on both of the methods can be found in [here](https://blog.usejournal.com/a-comparison-of-grid-search-and-randomized-search-using-scikit-learn-29823179bc85).

# %% [markdown]
# <a id="42"></a> <br>
# ## Grid Search
#
# Grid search is a traditional method to perform hyperparameter tunning. It basically works by defining a subset of candidate values for each hyperparameter, and training all the possible combination of the hyperparameters. Then, each possible fitted model is evaluated on a validation set, and the best configuration of the hyperparameter will be choosed at the end.

# %% [markdown]
# <a id="43"></a> <br>
# ## Early Stopping and Callback
#
# Since in the Grid Search, we have to train an LSTM model for each combination, it may take so much time to fit all the models and choose the best combination of the hyperparameters. One of the ways that we can prevent this from happening is through using Early Stopping and Callbacks. The idea here is to track a measure (like validation loss) and whenever a stopping criterion (like no improvement in the monitored measure value in successive steps, reaching a pre-specified limit for that measure, or a pre-specified increment in that measure) is satisfied, we can stop the training process. The measure that we are using here is validation loss since the validation set is not used in the training process. [This](https://machinelearningmastery.com/how-to-stop-training-deep-neural-networks-at-the-right-time-using-early-stopping/) article is one of the best articles that I've read about using Early Stopping to halt the training of a model at the right time. In the below, I copied and pasted the parts that I found important:
#
# > 1. **es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)** ****-->**** Often, the first sign of no further improvement may not be the best time to stop training. This is because the model may coast into a plateau of no improvement or even get slightly worse before getting much better. We can account for this by adding a delay to the trigger in terms of the number of epochs on which we would like to see no improvement. This can be done by setting the “patience” argument.
#
# > 2. **es = EarlyStopping(monitor='val_accuracy', mode='max', min_delta=1)** **-->** By default, any change in the performance measure, no matter how fractional, will be considered an improvement. You may want to consider an improvement that is a specific increment, such as 1 unit for mean squared error or 1% for accuracy. This can be specified via the “min_delta” argument.
#
# > 3. **es = EarlyStopping(monitor='val_loss', mode='min', baseline=0.4)** **-->**  Finally, it may be desirable to only stop training if performance stays above or below a given threshold or baseline. For example, if you have familiarity with the training of the model (e.g. learning curves) and know that once a validation loss of a given value is achieved that there is no point in continuing training. This can be specified by setting the “baseline” argument.
#
# > 4. **mc = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', verbose=1)** **-->** The EarlyStopping callback will stop training once triggered, but the model at the end of training may not be the model with best performance on the validation dataset. An additional callback is required that will save the best model observed during training for later use. This is the ModelCheckpoint callback.

# %%
# detect and init the TPU
# tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
# tf.config.experimental_connect_to_cluster(tpu)
# tf.tpu.experimental.initialize_tpu_system(tpu)

# instantiate a distribution strategy
# tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)


def LSTM_HyperParameter_Tuning(config, x_train, y_train, x_test, y_test):
    
    first_additional_layer, second_additional_layer, third_additional_layer, n_neurons, n_batch_size, dropout = config
    possible_combinations = list(itertools.product(first_additional_layer, second_additional_layer, third_additional_layer,
                                                  n_neurons, n_batch_size, dropout))
    
    print(possible_combinations)
    print('\n')
    
    hist = []
    
    for i in range(0, len(possible_combinations)):
        
        print(f'{i+1}th combination: \n')
        print('--------------------------------------------------------------------')
        
        first_additional_layer, second_additional_layer, third_additional_layer, n_neurons, n_batch_size, dropout = possible_combinations[i]
        
        # instantiating the model in the strategy scope creates the model on the TPU
        #with tpu_strategy.scope():
        regressor = Sequential()
        regressor.add(LSTM(units=n_neurons, return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2])))
        regressor.add(Dropout(dropout))

        if first_additional_layer:
            regressor.add(LSTM(units=n_neurons, return_sequences=True))
            regressor.add(Dropout(dropout))

        if second_additional_layer:
            regressor.add(LSTM(units=n_neurons, return_sequences=True))
            regressor.add(Dropout(dropout))

        if third_additional_layer:
            regressor.add(GRU(units=n_neurons, return_sequences=True))
            regressor.add(Dropout(dropout))

        regressor.add(LSTM(units=n_neurons, return_sequences=False))
        regressor.add(Dropout(dropout))
        regressor.add(Dense(units=5, activation='linear'))
        regressor.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])

        es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
        '''''
        From the mentioned article above --> If a validation dataset is specified to the fit() function via the validation_data or v
        alidation_split arguments,then the loss on the validation dataset will be made available via the name “val_loss.”
        '''''

        file_path = 'best_model.keras'

        mc = ModelCheckpoint(file_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)

        '''''
        cb = Callback(...)  # First, callbacks must be instantiated.
        cb_list = [cb, ...]  # Then, one or more callbacks that you intend to use must be added to a Python list.
        model.fit(..., callbacks=cb_list)  # Finally, the list of callbacks is provided to the callback argument when fitting the model.
        '''''

        regressor.fit(x_train, y_train, validation_split=0.3, epochs=40, batch_size=n_batch_size, callbacks=[es, mc], verbose=0)

        # load the best model
        # regressor = load_model('best_model.h5')

        train_accuracy = regressor.evaluate(x_train, y_train, verbose=0)
        test_accuracy = regressor.evaluate(x_test, y_test, verbose=0)

        hist.append(list((first_additional_layer, second_additional_layer, third_additional_layer, n_neurons, n_batch_size, dropout,
                          train_accuracy, test_accuracy)))

        print(f'{str(i)}-th combination = {possible_combinations[i]} \n train accuracy: {train_accuracy} and test accuracy: {test_accuracy}')
        
        print('--------------------------------------------------------------------')
        print('--------------------------------------------------------------------')
        print('--------------------------------------------------------------------')
        print('--------------------------------------------------------------------')
         
    return hist

# %%
config = [[False], [False], [False], [16, 32], [8, 16, 32], [0.2]]  

# list of lists --> [[first_additional_layer], [second_additional_layer], [third_additional_layer], [n_neurons], [n_batch_size], [dropout]]

hist = LSTM_HyperParameter_Tuning(config, X_train, y_train, X_test, y_test)  # change x_train shape
# Out:
# [(False, False, False, 16, 8, 0.2), (False, False, False, 16, 16, 0.2), (False, False, False, 16, 32, 0.2), (False, False, False, 32, 8, 0.2), (False, False, False, 32, 16, 0.2), (False, False, False, 32, 32, 0.2)]
#
#
# 1th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.00392, saving model to best_model.keras
#
# Epoch 2: val_loss did not improve from 0.00392
#
# Epoch 3: val_loss improved from 0.00392 to 0.00378, saving model to best_model.keras
#
# Epoch 4: val_loss improved from 0.00378 to 0.00316, saving model to best_model.keras
#
# Epoch 5: val_loss improved from 0.00316 to 0.00230, saving model to best_model.keras
#
# Epoch 6: val_loss improved from 0.00230 to 0.00212, saving model to best_model.keras
#
# Epoch 7: val_loss did not improve from 0.00212
#
# Epoch 8: val_loss did not improve from 0.00212
#
# Epoch 9: val_loss did not improve from 0.00212
#
# Epoch 10: val_loss improved from 0.00212 to 0.00189, saving model to best_model.keras
#
# Epoch 11: val_loss did not improve from 0.00189
#
# Epoch 12: val_loss did not improve from 0.00189
#
# Epoch 13: val_loss did not improve from 0.00189
#
# Epoch 14: val_loss did not improve from 0.00189
#
# Epoch 15: val_loss did not improve from 0.00189
#
# Epoch 16: val_loss did not improve from 0.00189
#
# Epoch 17: val_loss improved from 0.00189 to 0.00185, saving model to best_model.keras
#
# Epoch 18: val_loss did not improve from 0.00185
#
# Epoch 19: val_loss did not improve from 0.00185
#
# Epoch 20: val_loss did not improve from 0.00185
#
# Epoch 21: val_loss did not improve from 0.00185
#
# Epoch 22: val_loss did not improve from 0.00185
#
# Epoch 23: val_loss did not improve from 0.00185
#
# Epoch 24: val_loss did not improve from 0.00185
#
# Epoch 25: val_loss did not improve from 0.00185
#
# Epoch 26: val_loss did not improve from 0.00185
#
# Epoch 27: val_loss did not improve from 0.00185
# Epoch 27: early stopping
# 0-th combination = (False, False, False, 16, 8, 0.2)
#  train accuracy: [0.0011932449415326118, 0.03454337641596794] and test accuracy: [0.019550789147615433, 0.13982413709163666]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# 2th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.00517, saving model to best_model.keras
#
# Epoch 2: val_loss improved from 0.00517 to 0.00323, saving model to best_model.keras
#
# Epoch 3: val_loss improved from 0.00323 to 0.00256, saving model to best_model.keras
#
# Epoch 4: val_loss improved from 0.00256 to 0.00221, saving model to best_model.keras
#
# Epoch 5: val_loss improved from 0.00221 to 0.00186, saving model to best_model.keras
#
# Epoch 6: val_loss did not improve from 0.00186
#
# Epoch 7: val_loss did not improve from 0.00186
#
# Epoch 8: val_loss did not improve from 0.00186
#
# Epoch 9: val_loss did not improve from 0.00186
#
# Epoch 10: val_loss did not improve from 0.00186
#
# Epoch 11: val_loss did not improve from 0.00186
#
# Epoch 12: val_loss improved from 0.00186 to 0.00182, saving model to best_model.keras
#
# Epoch 13: val_loss did not improve from 0.00182
#
# Epoch 14: val_loss did not improve from 0.00182
#
# Epoch 15: val_loss did not improve from 0.00182
#
# Epoch 16: val_loss did not improve from 0.00182
#
# Epoch 17: val_loss did not improve from 0.00182
#
# Epoch 18: val_loss did not improve from 0.00182
#
# Epoch 19: val_loss improved from 0.00182 to 0.00165, saving model to best_model.keras
#
# Epoch 20: val_loss did not improve from 0.00165
#
# Epoch 21: val_loss did not improve from 0.00165
#
# Epoch 22: val_loss did not improve from 0.00165
#
# Epoch 23: val_loss did not improve from 0.00165
#
# Epoch 24: val_loss did not improve from 0.00165
#
# Epoch 25: val_loss did not improve from 0.00165
#
# Epoch 26: val_loss did not improve from 0.00165
#
# Epoch 27: val_loss did not improve from 0.00165
#
# Epoch 28: val_loss did not improve from 0.00165
#
# Epoch 29: val_loss did not improve from 0.00165
# Epoch 29: early stopping
# 1-th combination = (False, False, False, 16, 16, 0.2)
#  train accuracy: [0.0008264530915766954, 0.028748096898198128] and test accuracy: [0.0123133584856987, 0.11096557229757309]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# 3th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.01868, saving model to best_model.keras
#
# Epoch 2: val_loss improved from 0.01868 to 0.00225, saving model to best_model.keras
#
# Epoch 3: val_loss improved from 0.00225 to 0.00161, saving model to best_model.keras
#
# Epoch 4: val_loss improved from 0.00161 to 0.00101, saving model to best_model.keras
#
# Epoch 5: val_loss did not improve from 0.00101
#
# Epoch 6: val_loss did not improve from 0.00101
#
# Epoch 7: val_loss did not improve from 0.00101
#
# Epoch 8: val_loss did not improve from 0.00101
#
# Epoch 9: val_loss did not improve from 0.00101
#
# Epoch 10: val_loss did not improve from 0.00101
#
# Epoch 11: val_loss did not improve from 0.00101
#
# Epoch 12: val_loss did not improve from 0.00101
#
# Epoch 13: val_loss did not improve from 0.00101
#
# Epoch 14: val_loss did not improve from 0.00101
# Epoch 14: early stopping
# 2-th combination = (False, False, False, 16, 32, 0.2)
#  train accuracy: [0.0010565356351435184, 0.03250439465045929] and test accuracy: [0.01729729399085045, 0.13151918351650238]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# 4th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.00057, saving model to best_model.keras
#
# Epoch 2: val_loss did not improve from 0.00057
#
# Epoch 3: val_loss did not improve from 0.00057
#
# Epoch 4: val_loss did not improve from 0.00057
#
# Epoch 5: val_loss did not improve from 0.00057
#
# Epoch 6: val_loss did not improve from 0.00057
#
# Epoch 7: val_loss did not improve from 0.00057
#
# Epoch 8: val_loss did not improve from 0.00057
#
# Epoch 9: val_loss did not improve from 0.00057
#
# Epoch 10: val_loss did not improve from 0.00057
#
# Epoch 11: val_loss did not improve from 0.00057
# Epoch 11: early stopping
# 3-th combination = (False, False, False, 32, 8, 0.2)
#  train accuracy: [0.0004437163006514311, 0.021064573898911476] and test accuracy: [0.005450131371617317, 0.07382500171661377]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# 5th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.00089, saving model to best_model.keras
#
# Epoch 2: val_loss improved from 0.00089 to 0.00065, saving model to best_model.keras
#
# Epoch 3: val_loss did not improve from 0.00065
#
# Epoch 4: val_loss did not improve from 0.00065
#
# Epoch 5: val_loss did not improve from 0.00065
#
# Epoch 6: val_loss did not improve from 0.00065
#
# Epoch 7: val_loss did not improve from 0.00065
#
# Epoch 8: val_loss did not improve from 0.00065
#
# Epoch 9: val_loss did not improve from 0.00065
#
# Epoch 10: val_loss did not improve from 0.00065
#
# Epoch 11: val_loss did not improve from 0.00065
#
# Epoch 12: val_loss did not improve from 0.00065
# Epoch 12: early stopping
# 4-th combination = (False, False, False, 32, 16, 0.2)
#  train accuracy: [0.00033137790160253644, 0.01820378750562668] and test accuracy: [0.004104265011847019, 0.06406453996896744]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# 6th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.00206, saving model to best_model.keras
#
# Epoch 2: val_loss improved from 0.00206 to 0.00065, saving model to best_model.keras
#
# Epoch 3: val_loss improved from 0.00065 to 0.00049, saving model to best_model.keras
#
# Epoch 4: val_loss did not improve from 0.00049
#
# Epoch 5: val_loss did not improve from 0.00049
#
# Epoch 6: val_loss did not improve from 0.00049
#
# Epoch 7: val_loss did not improve from 0.00049
#
# Epoch 8: val_loss did not improve from 0.00049
#
# Epoch 9: val_loss did not improve from 0.00049
#
# Epoch 10: val_loss did not improve from 0.00049
#
# Epoch 11: val_loss did not improve from 0.00049
#
# Epoch 12: val_loss did not improve from 0.00049
#
# Epoch 13: val_loss did not improve from 0.00049
# Epoch 13: early stopping
# 5-th combination = (False, False, False, 32, 32, 0.2)
#  train accuracy: [0.0005056494846940041, 0.022486651316285133] and test accuracy: [0.007390292827039957, 0.0859668105840683]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# --------------------------------------------------------------------

# %% [markdown]
# <a id="44"></a> <br>
# ## Choosing the Best Model

# %%
hist = pd.DataFrame(hist)
hist = hist.sort_values(by=[7], ascending=True)
hist
# Out:
#        0      1      2   3   4    5  \
# 4  False  False  False  32  16  0.2
# 3  False  False  False  32   8  0.2
# 5  False  False  False  32  32  0.2
# 1  False  False  False  16  16  0.2
# 2  False  False  False  16  32  0.2
# 0  False  False  False  16   8  0.2
#
#                                                6  \
# 4  [0.00033137790160253644, 0.01820378750562668]
# 3  [0.0004437163006514311, 0.021064573898911476]
# 5  [0.0005056494846940041, 0.022486651316285133]
# 1  [0.0008264530915766954, 0.028748096898198128]
# 2   [0.0010565356351435184, 0.03250439465045929]
# 0   [0.0011932449415326118, 0.03454337641596794]
#
#                                              7
# 4  [0.004104265011847019, 0.06406453996896744]
# 3  [0.005450131371617317, 0.07382500171661377]
# 5   [0.007390292827039957, 0.0859668105840683]
# 1    [0.0123133584856987, 0.11096557229757309]
# 2   [0.01729729399085045, 0.13151918351650238]
# 0  [0.019550789147615433, 0.13982413709163666]

# %% [markdown]
# <a id="5"></a> <br>
# ## Results

# %%
print(f'Best Combination: \n first_additional_layer = {hist.iloc[0, 0]}\n second_additional_layer = {hist.iloc[0, 1]}\n third_additional_layer = {hist.iloc[0, 2]}\n n_neurons = {hist.iloc[0, 3]}\n n_batch_size = {hist.iloc[0, 4]}\n dropout = {hist.iloc[0, 5]}')
print('**************************')
print(f'Results Before Tunning:\n Test Set RMSE: {np.round(results, 4)[1]}\n')
print(f'Results After Tunning:\n Test Set RMSE: {np.round(hist.iloc[0, -1], 4)[1]}\n')
print(f'{np.round((results[1] - hist.iloc[0, -1][1])*100/np.round(results, 4)[1])}% Improvement')
# Out:
# Best Combination:
#  first_additional_layer = False
#  second_additional_layer = False
#  third_additional_layer = False
#  n_neurons = 32
#  n_batch_size = 16
#  dropout = 0.2
# **************************
# Results Before Tunning:
#  Test Set RMSE: 0.121
#
# Results After Tunning:
#  Test Set RMSE: 0.0641
#
# 47.0% Improvement

# %%
first_additional_layer, second_additional_layer, third_additional_layer, n_neurons, n_batch_size, dropout = list(hist.iloc[0, :-2])

# %%
print(type(n_neurons))
n_neurons = int(n_neurons)
print(type(n_neurons))
# Out:
# <class 'numpy.int64'>
# <class 'int'>

# %%
regressor = Sequential()
regressor.add(LSTM(units=n_neurons, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
regressor.add(Dropout(dropout))

if first_additional_layer:
    regressor.add(LSTM(units=n_neurons, return_sequences=True))
    regressor.add(Dropout(dropout))

if second_additional_layer:
    regressor.add(LSTM(units=n_neurons, return_sequences=True))
    regressor.add(Dropout(dropout))

if third_additional_layer:
    regressor.add(GRU(units=n_neurons, return_sequences=True))
    regressor.add(Dropout(dropout))

regressor.add(LSTM(units=n_neurons, return_sequences=False))
regressor.add(Dropout(dropout))
regressor.add(Dense(units=5, activation='linear'))
regressor.compile(optimizer='adam', loss='mse')

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

file_path = 'best_model.keras'

mc = ModelCheckpoint(file_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)

regressor.fit(X_train, y_train, validation_split=0.3, epochs=40, batch_size=n_batch_size, callbacks=[es, mc], verbose=0)
# Out:
# /Users/patten/my_files/大學課業/大三/資料探勘/project/original/.venv/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: val_loss improved from inf to 0.00083, saving model to best_model.keras
#
# Epoch 2: val_loss did not improve from 0.00083
#
# Epoch 3: val_loss did not improve from 0.00083
#
# Epoch 4: val_loss did not improve from 0.00083
#
# Epoch 5: val_loss did not improve from 0.00083
#
# Epoch 6: val_loss did not improve from 0.00083
# Epoch 6: early stopping

# %%
regressor.evaluate(X_test, y_test)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0075
# 0.007862135767936707

# %%
regressor = keras.models.load_model("best_model.keras")
y_pred = regressor.predict(np.expand_dims(X_test[0], axis=0))
plt.figure(figsize=(16,8), dpi= 100, facecolor='w', edgecolor='k')

plt.plot(y_test[0:5], color='red', label = 'Real Opening Price')
plt.plot(np.arange(0, 5), y_pred[0], "gx", label = 'Predicted Opening Price')
plt.legend(loc='best')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step

# %% [markdown]
# As it is clear in the plot, the trend (rise and fall) of the stock price is well predicted. Nice!

# %%
print(y_pred.shape)
# Out:
# (1, 5)

# %%
y_pred_new = []
print(y_pred)
for i in range(len(y_pred[0])):
    y_pred_new.append([y_pred[0][i], y_pred[0][i], y_pred[0][i], y_pred[0][i], y_pred[0][i]])
print(y_pred_new)
for i in range(len(y_pred_new)):
    print(sc.inverse_transform(y_pred_new)[i][0])
# Out:
# [[0.705555   0.73078275 0.68242204 0.64805657 0.71190464]]
# [[0.705555, 0.705555, 0.705555, 0.705555, 0.705555], [0.73078275, 0.73078275, 0.73078275, 0.73078275, 0.73078275], [0.68242204, 0.68242204, 0.68242204, 0.68242204, 0.68242204], [0.64805657, 0.64805657, 0.64805657, 0.64805657, 0.64805657], [0.71190464, 0.71190464, 0.71190464, 0.71190464, 0.71190464]]
# 577.8762724590341
# 596.4791972974878
# 560.8180130567463
# 535.4769115919314
# 582.5584846218302

# %% [markdown]
# # If you liked my work then please upvote, Thank you.

# %%
# Creating a data structure (it does not work when you have only one feature)
def create_data_2(df, n_future, n_past, train_test_split_percentage, validation_split_percentage):
    n_feature = df.shape[1]
    x_data, y_data = [], []
    x_data.append(df[len(df) - n_past:len(df), 0:n_feature])
    
    return np.array(x_data)

# %%
# Number of days you want to predict into the future
# Number of past days you want to use to predict the future

X_data = create_data_2(data_prices_scaled, n_future=5, n_past=5, train_test_split_percentage=0.8,
                                               validation_split_percentage = 0)

# %%
print(X_data.shape)
# Out:
# (1, 5, 5)

# %%
regressor = keras.models.load_model("best_model.keras")
y_pred = regressor.predict(np.expand_dims(X_data[0], axis=0))

plt.figure(figsize=(16,8), dpi= 100, facecolor='w', edgecolor='k')

plt.plot(y_pred[0], color="green", label = 'Predicted Opening Price')
plt.legend(loc='best')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step

# %%
print(y_pred.shape)
# Out:
# (1, 5)

# %%
y_pred_new = []
for i in range(len(y_pred[0])):
    # print(y_pred[i])
    y_pred_new.append([y_pred[0][i], y_pred[0][i], y_pred[0][i], y_pred[0][i], y_pred[0][i]])
print(y_pred_new[0])
for i in range(len(y_pred_new)):
    print(sc.inverse_transform(y_pred_new)[i][0])
print(len(y_pred))
plt.figure(figsize=(16,8), dpi= 100, facecolor='w', edgecolor='k')
plt.plot(sc.inverse_transform(y_pred_new)[:, 0], color="green", label = 'Predicted Opening Price')
plt.legend(loc='best')
# Out:
# [0.9394717, 0.9394717, 0.9394717, 0.9394717, 0.9394717]
# 750.3664474230413
# 773.3791670451267
# 715.4648496854816
# 671.1306573488406
# 741.4477450468048
# 1
